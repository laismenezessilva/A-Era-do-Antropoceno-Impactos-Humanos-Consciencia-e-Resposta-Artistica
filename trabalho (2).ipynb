# %% [markdown]
# Apredendo a usar o Phyton

# %% [markdown]
# !pip install pandas

# %%
# !pip install basedosdados
# Out:
# Requirement already satisfied: basedosdados in c:\users\laism\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: google-api-python-client<3.0,>=2.86 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.170.0)
# Requirement already satisfied: google-cloud-bigquery<4.0,>=3.10 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (3.34.0)
# Requirement already satisfied: google-cloud-bigquery-connection<2.0,>=1.12 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (1.18.2)
# Requirement already satisfied: google-cloud-bigquery-storage<3.0,>=2.19 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.32.0)
# Requirement already satisfied: google-cloud-storage<3.0,>=2.9 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.19.0)
# Requirement already satisfied: loguru<0.8.0,>=0.7.0 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (0.7.3)
# Requirement already satisfied: pandas<3.0,>=2.0 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.2.2)
# Requirement already satisfied: pandas-gbq>=0.19 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (0.29.0)
# Requirement already satisfied: pydata-google-auth<2.0,>=1.8 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (1.9.1)
# Requirement already satisfied: tomlkit<0.12,>=0.11 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (0.11.1)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (4.66.5)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (2.40.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.32.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (5.29.5)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-storage<3.0,>=2.9->basedosdados) (1.7.1)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\laism\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.0->basedosdados) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\laism\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.0->basedosdados) (1.2.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\laism\anaconda3\lib\site-packages (from pandas<3.0,>=2.0->basedosdados) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laism\anaconda3\lib\site-packages (from pandas<3.0,>=2.0->basedosdados) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laism\anaconda3\lib\site-packages (from pandas<3.0,>=2.0->basedosdados) (2023.3)
# Requirement already satisfied: setuptools in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (75.1.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (1.4.3)
# Requirement already satisfied: pyarrow>=4.0.0 in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (16.1.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (1.2.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\laism\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0,>=2.86->basedosdados) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\laism\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\laism\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\laism\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\laism\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\laism\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\laism\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq>=0.19->basedosdados) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\laism\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0,>=2.86->basedosdados) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\laism\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (2025.4.26)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\laism\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\laism\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq>=0.19->basedosdados) (3.2.2)

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\laism\anaconda3\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\laism\anaconda3\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\laism\anaconda3\lib\site-packages (from plotly) (25.0)

# %%
import basedosdados as bd

# %%
    # ?bd.read_table
# Out:
# Signature:
# bd.read_table(
#     dataset_id: str,
#     table_id: str,
#     billing_project_id: Optional[str] = None,
#     query_project_id: str = 'basedosdados',
#     limit: Optional[int] = None,
#     from_file: bool = False,
#     reauth: bool = False,
#     use_bqstorage_api: bool = False,
# ) -> pandas.core.frame.DataFrame
# Docstring:
# Load data from BigQuery using dataset_id and table_id.
#
# Args:
#     dataset_id (str):
#         Dataset id available in basedosdados. It should always come with
#         table_id.
#     table_id (str):
#         Table id available in basedosdados.dataset_id.
#         It should always come with dataset_id.
#     billing_project_id (str): Optional.
#         Project that will be billed. Find your Project ID here
#         https://console.cloud.google.com/projectselector2/home/dashboard
#     query_project_id (str): Optional.
#         Which project the table lives. You can change this you want to query
#         different projects.
#     limit (int): Optional.
#         Number of rows to read from table.
#     from_file (boolean): Optional.
#         Uses the credentials from file, located in `~/.basedosdados/credentials/
#     reauth (boolean): Optional.
#         Re-authorize Google Cloud Project in case you need to change user or
#         reset configurations.
#     use_bqstorage_api (boolean): Optional.
#         Use the BigQuery Storage API to download query results quickly, but
#         at an increased cost(https://cloud.google.com/bigquery/docs/reference/storage/).
#         To use this API, first enable it in the Cloud Console(https://console.cloud.google.com/apis/library/bigquerystorage.googleapis.com).
#         You must also have the bigquery.readsessions.create permission on
#         the project you are billing queries to.
#
# Returns:
#     pd.DataFrame:
#         Query result
# File:      c:\users\laism\anaconda3\lib\site-packages\basedosdados\download\download.py
# Type:      function

# %%
pip install --upgrade basedosdados pandas
# Out:
# Requirement already satisfied: basedosdados in c:\users\laism\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pandas in c:\users\laism\anaconda3\lib\site-packages (2.2.2)
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: google-api-python-client<3.0,>=2.86 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.170.0)
# Requirement already satisfied: google-cloud-bigquery<4.0,>=3.10 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (3.34.0)
# Requirement already satisfied: google-cloud-bigquery-connection<2.0,>=1.12 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (1.18.2)
# Requirement already satisfied: google-cloud-bigquery-storage<3.0,>=2.19 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.32.0)
# Requirement already satisfied: google-cloud-storage<3.0,>=2.9 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.19.0)
# Requirement already satisfied: loguru<0.8.0,>=0.7.0 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (0.7.3)
# Requirement already satisfied: pandas-gbq>=0.19 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (0.29.0)
# Requirement already satisfied: pydata-google-auth<2.0,>=1.8 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (1.9.1)
# Requirement already satisfied: tomlkit<0.12,>=0.11 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (0.11.1)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (4.66.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\laism\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laism\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laism\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laism\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (2.40.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (25.0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.32.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (5.29.5)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-storage<3.0,>=2.9->basedosdados) (1.7.1)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\laism\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.0->basedosdados) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\laism\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.0->basedosdados) (1.2.0)
# Requirement already satisfied: setuptools in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (75.1.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (1.4.3)
# Requirement already satisfied: pyarrow>=4.0.0 in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (16.1.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (1.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\laism\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\laism\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0,>=2.86->basedosdados) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\laism\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\laism\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\laism\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\laism\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\laism\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\laism\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq>=0.19->basedosdados) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\laism\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0,>=2.86->basedosdados) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (2025.4.26)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\laism\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\laism\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq>=0.19->basedosdados) (3.2.2)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    -------------------------- ------------- 7.6/11.5 MB 39.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 36.0 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# Successfully installed pandas-2.2.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.37.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.

# %%
    import basedosdados as bd
    
    billing_id = "trabalho-mc"
    
    query = """
      SELECT
        dados.ano as ano,
        dados.id_municipio AS id_municipio,
        diretorio_id_municipio.nome AS id_municipio_nome,
        dados.bioma as bioma,
        dados.area_total as area_total,
        dados.desmatado as desmatado,
        dados.vegetacao_natural as vegetacao_natural,
        dados.nao_vegetacao_natural as nao_vegetacao_natural,
        dados.hidrografia as hidrografia
    FROM `basedosdados.br_inpe_prodes.municipio_bioma` AS dados
    LEFT JOIN (SELECT DISTINCT id_municipio,nome  FROM `basedosdados.br_bd_diretorios_brasil.municipio`) AS diretorio_id_municipio
        ON dados.id_municipio = diretorio_id_municipio.id_municipio
    """a
# Out:
# Downloading: 100%|██████████|
#          ano id_municipio       id_municipio_nome           bioma  \
# 0       2009      5102504                 Cáceres        Pantanal
# 1       2011      5102504                 Cáceres        Pantanal
# 2       2010      5102504                 Cáceres        Pantanal
# 3       2005      5102504                 Cáceres        Pantanal
# 4       2002      5102504                 Cáceres        Pantanal
# ...      ...          ...                     ...             ...
# 156859  2015      4306551  Dom Pedro de Alcântara  Mata Atlântica
# 156860  2005      4306551  Dom Pedro de Alcântara  Mata Atlântica
# 156861  2019      4306551  Dom Pedro de Alcântara  Mata Atlântica
# 156862  2004      4306551  Dom Pedro de Alcântara  Mata Atlântica
# 156863  2003      4306551  Dom Pedro de Alcântara  Mata Atlântica
#
#          area_total  desmatado  vegetacao_natural  nao_vegetacao_natural  \
# 0       17422.29079     3124.8            12616.5                    0.4
# 1       17422.29079     3203.4            12537.9                    0.4
# 2       17422.29079     3157.8            12583.5                    0.4
# 3       17422.29079     2937.1            12804.2                    0.4
# 4       17422.29079     2598.0            13143.3                    0.4
# ...             ...        ...                ...                    ...
# 156859     78.29205       44.5               18.7                    0.0
# 156860     78.29205       44.0               19.2                    0.0
# 156861     78.29205       44.9               18.3                    0.0
# 156862     78.29205       44.0               19.2                    0.0
# 156863     78.29205       43.9               19.3                    0.0
#
#         hidrografia
# 0            1680.6
# 1            1680.6
# 2            1680.6
# 3            1680.6
# 4            1680.6
# ...             ...
# 156859         15.1
# 156860         15.1
# 156861         15.1
# 156862         15.1
# 156863         15.1
#
# [156864 rows x 9 columns]

# %%
import pandas as pd

# %%
import basedosdados as bd

# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in c:\users\laism\anaconda3\lib\site-packages (6.28.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\laism\anaconda3\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in c:\users\laism\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\laism\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\laism\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\laism\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\laism\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: colorama in c:\users\laism\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laism\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\laism\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\laism\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (305.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\laism\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\laism\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\laism\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing in c:\users\laism\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\laism\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\laism\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\laism\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\laism\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\laism\anaconda3\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\laism\anaconda3\lib\site-packages (from nbformat) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\laism\anaconda3\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\laism\anaconda3\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\laism\anaconda3\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\laism\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\laism\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\laism\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\laism\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\laism\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\laism\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (305.1)

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\laism\anaconda3\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\laism\anaconda3\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\laism\anaconda3\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\laism\anaconda3\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\laism\anaconda3\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\laism\anaconda3\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laism\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laism\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laism\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\laism\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
# !pip install basedosdados
# Out:
# Requirement already satisfied: basedosdados in c:\users\laism\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: google-api-python-client<3.0,>=2.86 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.170.0)
# Requirement already satisfied: google-cloud-bigquery<4.0,>=3.10 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (3.34.0)
# Requirement already satisfied: google-cloud-bigquery-connection<2.0,>=1.12 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (1.18.2)
# Requirement already satisfied: google-cloud-bigquery-storage<3.0,>=2.19 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.32.0)
# Requirement already satisfied: google-cloud-storage<3.0,>=2.9 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.19.0)
# Requirement already satisfied: loguru<0.8.0,>=0.7.0 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (0.7.3)
# Requirement already satisfied: pandas<3.0,>=2.0 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (2.2.3)
# Requirement already satisfied: pandas-gbq>=0.19 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (0.29.0)
# Requirement already satisfied: pydata-google-auth<2.0,>=1.8 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (1.9.1)
# Requirement already satisfied: tomlkit<0.12,>=0.11 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (0.11.1)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\laism\anaconda3\lib\site-packages (from basedosdados) (4.66.5)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (2.40.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\laism\anaconda3\lib\site-packages (from google-api-python-client<3.0,>=2.86->basedosdados) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.32.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (5.29.5)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-bigquery-connection<2.0,>=1.12->basedosdados) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\laism\anaconda3\lib\site-packages (from google-cloud-storage<3.0,>=2.9->basedosdados) (1.7.1)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\laism\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.0->basedosdados) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\laism\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.0->basedosdados) (1.2.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\laism\anaconda3\lib\site-packages (from pandas<3.0,>=2.0->basedosdados) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laism\anaconda3\lib\site-packages (from pandas<3.0,>=2.0->basedosdados) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laism\anaconda3\lib\site-packages (from pandas<3.0,>=2.0->basedosdados) (2023.3)
# Requirement already satisfied: setuptools in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (75.1.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (1.4.3)
# Requirement already satisfied: pyarrow>=4.0.0 in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (16.1.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in c:\users\laism\anaconda3\lib\site-packages (from pandas-gbq>=0.19->basedosdados) (1.2.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\laism\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0,>=2.86->basedosdados) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\laism\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\laism\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\laism\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\laism\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\laism\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\laism\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq>=0.19->basedosdados) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\laism\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0,>=2.86->basedosdados) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\laism\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0,>=3.10->basedosdados) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery<4.0,>=3.10->basedosdados) (2025.4.26)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\laism\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0,>=2.86->basedosdados) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\laism\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq>=0.19->basedosdados) (3.2.2)

# %%
query = """
    SELECT
        dados.ano as ano,
        dados.id_municipio AS id_municipio,
        diretorio_id_municipio.nome AS id_municipio_nome,
        dados.bioma as bioma,
        dados.area_total as area_total,
        dados.desmatado as desmatado,
        dados.vegetacao_natural as vegetacao_natural,
        dados.nao_vegetacao_natural as nao_vegetacao_natural,
        dados.hidrografia as hidrografia
    FROM `basedosdados.br_inpe_prodes.municipio_bioma` AS dados
    LEFT JOIN (SELECT DISTINCT id_municipio,nome  FROM `basedosdados.br_bd_diretorios_brasil.municipio`) AS diretorio_id_municipio
        ON dados.id_municipio = diretorio_id_municipio.id_municipio
"""

# %%
print("Executando a consulta... Isso pode levar um tempo.")
df = bd.read_sql(query, billing_project_id="trabalho-mc")
print("Consulta concluída e dados carregados no DataFrame 'df'.")
# Out:
# Executando a consulta... Isso pode levar um tempo.
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
# Consulta concluída e dados carregados no DataFrame 'df'.

# %%
print("\nInformações gerais do DataFrame:")
print(df.info())
# Out:
# Informações gerais do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156864 entries, 0 to 156863
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ano                    156864 non-null  Int64
#  1   id_municipio           156864 non-null  object
#  2   id_municipio_nome      156864 non-null  object
#  3   bioma                  156864 non-null  object
#  4   area_total             156864 non-null  float64
#  5   desmatado              156864 non-null  float64
#  6   vegetacao_natural      156864 non-null  float64
#  7   nao_vegetacao_natural  156864 non-null  float64
#  8   hidrografia            156864 non-null  float64
# dtypes: Int64(1), float64(5), object(3)
# memory usage: 10.9+ MB
# None

# %%
print("\nPrimeiras 5 linhas do DataFrame:")
print(df.head())
# Out:
# Primeiras 5 linhas do DataFrame:
#     ano id_municipio id_municipio_nome     bioma   area_total  desmatado  \
# 0  2009      5102504           Cáceres  Pantanal  17422.29079     3124.8
# 1  2011      5102504           Cáceres  Pantanal  17422.29079     3203.4
# 2  2010      5102504           Cáceres  Pantanal  17422.29079     3157.8
# 3  2005      5102504           Cáceres  Pantanal  17422.29079     2937.1
# 4  2002      5102504           Cáceres  Pantanal  17422.29079     2598.0
#
#    vegetacao_natural  nao_vegetacao_natural  hidrografia
# 0            12616.5                    0.4       1680.6
# 1            12537.9                    0.4       1680.6
# 2            12583.5                    0.4       1680.6
# 3            12804.2                    0.4       1680.6
# 4            13143.3                    0.4       1680.6

# %%
df.to_csv("dados_prodes_municipio_bioma.csv", index=False)
# print("\nDados salvos em 'dados_prodes_municipio_bioma.csv'")

# %%
print(df.head())
# Out:
#     ano id_municipio id_municipio_nome     bioma   area_total  desmatado  \
# 0  2009      5102504           Cáceres  Pantanal  17422.29079     3124.8
# 1  2011      5102504           Cáceres  Pantanal  17422.29079     3203.4
# 2  2010      5102504           Cáceres  Pantanal  17422.29079     3157.8
# 3  2005      5102504           Cáceres  Pantanal  17422.29079     2937.1
# 4  2002      5102504           Cáceres  Pantanal  17422.29079     2598.0
#
#    vegetacao_natural  nao_vegetacao_natural  hidrografia
# 0            12616.5                    0.4       1680.6
# 1            12537.9                    0.4       1680.6
# 2            12583.5                    0.4       1680.6
# 3            12804.2                    0.4       1680.6
# 4            13143.3                    0.4       1680.6

# %%
print(df.tail())
# Out:
#          ano id_municipio       id_municipio_nome           bioma  area_total  \
# 156859  2015      4306551  Dom Pedro de Alcântara  Mata Atlântica    78.29205
# 156860  2005      4306551  Dom Pedro de Alcântara  Mata Atlântica    78.29205
# 156861  2019      4306551  Dom Pedro de Alcântara  Mata Atlântica    78.29205
# 156862  2004      4306551  Dom Pedro de Alcântara  Mata Atlântica    78.29205
# 156863  2003      4306551  Dom Pedro de Alcântara  Mata Atlântica    78.29205
#
#         desmatado  vegetacao_natural  nao_vegetacao_natural  hidrografia
# 156859       44.5               18.7                    0.0         15.1
# 156860       44.0               19.2                    0.0         15.1
# 156861       44.9               18.3                    0.0         15.1
# 156862       44.0               19.2                    0.0         15.1
# 156863       43.9               19.3                    0.0         15.1

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156864 entries, 0 to 156863
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ano                    156864 non-null  Int64
#  1   id_municipio           156864 non-null  object
#  2   id_municipio_nome      156864 non-null  object
#  3   bioma                  156864 non-null  object
#  4   area_total             156864 non-null  float64
#  5   desmatado              156864 non-null  float64
#  6   vegetacao_natural      156864 non-null  float64
#  7   nao_vegetacao_natural  156864 non-null  float64
#  8   hidrografia            156864 non-null  float64
# dtypes: Int64(1), float64(5), object(3)
# memory usage: 10.9+ MB
# None

# %%
print(df.describe())
# Out:
#             ano     area_total      desmatado  vegetacao_natural  \
# count  156864.0  156864.000000  156864.000000      156864.000000
# mean     2011.5    1299.785309     426.763920         808.250783
# std    6.922209    5160.295563     759.938414        4577.263624
# min      2000.0       0.000000       0.000000         -17.200000
# 25%     2005.75     155.994450      91.200000          25.700000
# 50%      2011.5     336.271655     195.100000          83.500000
# 75%     2017.25     849.356528     434.125000         341.700000
# max      2023.0  159482.273990   21299.100000      151901.600000
#
#        nao_vegetacao_natural    hidrografia
# count          156864.000000  156864.000000
# mean               43.356196      21.414137
# std               439.724057     154.970068
# min                 0.000000       0.000000
# 25%                 0.000000       0.000000
# 50%                 0.000000       0.100000
# 75%                 0.000000       3.000000
# max             16957.500000    4500.200000

# %%
print(df['ano'].unique())
print(df['bioma'].unique())
print(df['id_municipio_nome'].unique())
# Out:
# <IntegerArray>
# [2009, 2011, 2010, 2005, 2002, 2004, 2014, 2006, 2017, 2016, 2008, 2015, 2020,
#  2012, 2000, 2018, 2021, 2003, 2022, 2019, 2007, 2023, 2001, 2013]
# Length: 24, dtype: Int64
# ['Pantanal' 'Pampa' 'Cerrado' 'Caatinga' 'Amazônia' 'Mata Atlântica']
# ['Cáceres' 'Sonora' 'Rondonópolis' ... 'Barão de Cotegipe'
#  'Flor do Sertão' 'Dom Pedro de Alcântara']

# %%
print(df['bioma'].nunique())
# Out:
# 6

# %%
print(df.isnull().sum())
# Out:
# ano                      0
# id_municipio             0
# id_municipio_nome        0
# bioma                    0
# area_total               0
# desmatado                0
# vegetacao_natural        0
# nao_vegetacao_natural    0
# hidrografia              0
# dtype: int64

# %%
# Certifique-se de que o DataFrame 'df' está carregado.

# Agrupar por 'bioma' e 'ano' e somar a coluna 'desmatado'
desmatamento_por_bioma_ano = df.groupby(['bioma', 'ano'])['desmatado'].sum().reset_index()

# Exibir as primeiras linhas do resultado
print("Total de desmatamento por bioma ao longo dos anos:")
print(desmatamento_por_bioma_ano.head())

# Opcional: Para ver o total de desmatamento de um bioma específico ao longo dos anos,
# por exemplo, para a Amazônia:
# print("\nDesmatamento na Amazônia por ano:")
# print(desmatamento_por_bioma_ano[desmatamento_por_bioma_ano['bioma'] == 'AMAZONIA'])

# Opcional: Para ver o total de desmatamento por bioma (totalizando todos os anos)
# desmatamento_total_por_bioma = df.groupby('bioma')['desmatado'].sum().reset_index()
# print("\nDesmatamento total por bioma (todos os anos combinados):")
# print(desmatamento_total_por_bioma)
# Out:
# Total de desmatamento por bioma ao longo dos anos:
#       bioma   ano  desmatado
# 0  Amazônia  2000   474934.6
# 1  Amazônia  2001   527870.0
# 2  Amazônia  2002   552402.0
# 3  Amazônia  2003   581385.6
# 4  Amazônia  2004   607431.0

# %%
print("Total de desmatamento por bioma ao longo dos anos (completo):")
print(desmatamento_por_bioma_ano)
# Out:
# Total de desmatamento por bioma ao longo dos anos (completo):
#         bioma   ano  desmatado
# 0    Amazônia  2000   474934.6
# 1    Amazônia  2001   527870.0
# 2    Amazônia  2002   552402.0
# 3    Amazônia  2003   581385.6
# 4    Amazônia  2004   607431.0
# ..        ...   ...        ...
# 139  Pantanal  2019    27377.1
# 140  Pantanal  2020    28054.8
# 141  Pantanal  2021    28879.2
# 142  Pantanal  2022    29668.5
# 143  Pantanal  2023    30391.7
#
# [144 rows x 3 columns]

# %%
print("\nBiomas únicos no DataFrame original:")
print(df['bioma'].unique())
# Out:
# Biomas únicos no DataFrame original:
# ['Pantanal' 'Pampa' 'Cerrado' 'Caatinga' 'Amazônia' 'Mata Atlântica']

# %%
desmatamento_por_bioma_ano_ordenado = desmatamento_por_bioma_ano.sort_values(
    by='desmatado', ascending=False
)
print("\nTotal de desmatamento por bioma e ano (ordenado por desmatamento):")
print(desmatamento_por_bioma_ano_ordenado.head(10)) # Mostrando os 10 maiores
# Out:
# Total de desmatamento por bioma e ano (ordenado por desmatamento):
#       bioma   ano  desmatado
# 71  Cerrado  2023  1017149.9
# 70  Cerrado  2022  1006135.5
# 69  Cerrado  2021   995448.8
# 68  Cerrado  2020   986918.1
# 67  Cerrado  2019   979012.6
# 66  Cerrado  2018   972693.2
# 65  Cerrado  2017   965432.8
# 64  Cerrado  2016   958317.2
# 63  Cerrado  2015   950819.6
# 62  Cerrado  2014   939691.7

# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\laism\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\laism\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\laism\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\laism\anaconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laism\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laism\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\laism\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 1. Calcular o desmatamento total para cada bioma (somando todos os anos)
# Certifique-se de que o DataFrame 'df' está carregado.
desmatamento_total_por_bioma = df.groupby('bioma')['desmatado'].sum().reset_index()

# 2. Ordenar os dados para que os maiores pedaços fiquem mais visíveis
desmatamento_total_por_bioma = desmatamento_total_por_bioma.sort_values(by='desmatado', ascending=False)

# 3. Criar o gráfico de pizza
plt.figure(figsize=(10, 10)) # Tamanho da figura para um gráfico de pizza
plt.pie(
    desmatamento_total_por_bioma['desmatado'],
    labels=desmatamento_total_por_bioma['bioma'],
    autopct='%1.1f%%', # Formato para exibir a porcentagem em cada fatia
    startangle=90,     # Começa a primeira fatia no topo (90 graus)
    pctdistance=0.85,  # Posição das porcentagens dentro das fatias
    wedgeprops={'edgecolor': 'black'} # Adiciona uma borda nas fatias
)

plt.title('Participação de Cada Bioma no Desmatamento Total (Todos os Anos)') # Título do gráfico
plt.axis('equal') # Garante que o gráfico de pizza seja um círculo
plt.show() # Exibe o gráfico

# %%
# Verifique as colunas do seu DataFrame 'df'
print(df.columns)

# E veja as primeiras linhas para ter certeza do que está lá
print(df.head())
# Out:
# Index(['valor_en', 'valor_pt', 'chave'], dtype='object')
#                           valor_en                           valor_pt chave
# 0                        1. Forest                        1. Floresta     1
# 1  2. Non Forest Natural Formation  2. Formação Natural não Florestal    10
# 2                       3. Farming                    3. Agropecuária    14
# 3            4. Non vegetated area               4. Área não Vegetada    22
# 4                         5. Water                    5. Corpo D'água    26

# %%
import basedosdados as bd
import pandas as pd

# Mantenha seu billing_id
billing_id = "trabalho-mc"

# A SUA QUERY SQL ORIGINAL para dados de desmatamento por município e bioma
query_original_df = """
    SELECT
        dados.ano as ano,
        dados.id_municipio AS id_municipio,
        diretorio_id_municipio.nome AS id_municipio_nome,
        dados.bioma as bioma,
        dados.area_total as area_total,
        dados.desmatado as desmatado,
        dados.vegetacao_natural as vegetacao_natural,
        dados.nao_vegetacao_natural as nao_vegetacao_natural,
        dados.hidrografia as hidrografia
    FROM `basedosdados.br_inpe_prodes.municipio_bioma` AS dados
    LEFT JOIN (SELECT DISTINCT id_municipio,nome  FROM `basedosdados.br_bd_diretorios_brasil.municipio`) AS diretorio_id_municipio
        ON dados.id_municipio = diretorio_id_municipio.id_municipio
"""

# Recarregar o DataFrame 'df' com os dados originais de desmatamento
print("Recarregando o DataFrame 'df' com os dados de desmatamento por município e bioma...")
df = bd.read_sql(query_original_df, billing_project_id=billing_id)
print("DataFrame 'df' recarregado com sucesso.")

# Verificar as primeiras linhas para confirmar que agora está correto
print("\nPrimeiras 5 linhas do DataFrame 'df' recarregado:")
print(df.head())
print("\nColunas do DataFrame 'df' recarregado:")
print(df.columns)
# Out:
# Recarregando o DataFrame 'df' com os dados de desmatamento por município e bioma...
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
# DataFrame 'df' recarregado com sucesso.
#
# Primeiras 5 linhas do DataFrame 'df' recarregado:
#     ano id_municipio id_municipio_nome     bioma   area_total  desmatado  \
# 0  2009      5102504           Cáceres  Pantanal  17422.29079     3124.8
# 1  2011      5102504           Cáceres  Pantanal  17422.29079     3203.4
# 2  2010      5102504           Cáceres  Pantanal  17422.29079     3157.8
# 3  2005      5102504           Cáceres  Pantanal  17422.29079     2937.1
# 4  2002      5102504           Cáceres  Pantanal  17422.29079     2598.0
#
#    vegetacao_natural  nao_vegetacao_natural  hidrografia
# 0            12616.5                    0.4       1680.6
# 1            12537.9                    0.4       1680.6
# 2            12583.5                    0.4       1680.6
# 3            12804.2                    0.4       1680.6
# 4            13143.3                    0.4       1680.6
#
# Colunas do DataFrame 'df' recarregado:
# Index(['ano', 'id_municipio', 'id_municipio_nome', 'bioma', 'area_total',
#        'desmatado', 'vegetacao_natural', 'nao_vegetacao_natural',
#        'hidrografia'],
#       dtype='object')

# %%
# --- Análise para o ano de 2020 ---
print("\n--- Análise para o ano de 2020 ---")
df_2020 = df[df['ano'] == 2020]

if not df_2020.empty:
    desmatamento_municipio_2020 = df_2020.groupby('id_municipio_nome')['desmatado'].sum().reset_index()
    municipio_maior_desmatamento_2020 = desmatamento_municipio_2020.loc[desmatamento_municipio_2020['desmatado'].idxmax()]

    print(f"Município com a maior área desmatada em 2020:")
    print(f"Nome: {municipio_maior_desmatamento_2020['id_municipio_nome']}")
    print(f"Área Desmatada: {municipio_maior_desmatamento_2020['desmatado']:.2f} km²")
else:
    print("Não há dados disponíveis para o ano de 2020 no DataFrame 'df'.")


# --- Análise para o ano de 2022 ---
print("\n--- Análise para o ano de 2022 ---")
df_2022 = df[df['ano'] == 2022]

if not df_2022.empty:
    desmatamento_municipio_2022 = df_2022.groupby('id_municipio_nome')['desmatado'].sum().reset_index()
    municipio_maior_desmatamento_2022 = desmatamento_municipio_2022.loc[desmatamento_municipio_2022['desmatado'].idxmax()]

    print(f"Município com a maior área desmatada em 2022:")
    print(f"Nome: {municipio_maior_desmatamento_2022['id_municipio_nome']}")
    print(f"Área Desmatada: {municipio_maior_desmatamento_2022['desmatado']:.2f} km²")
else:
    print("Não há dados disponíveis para o ano de 2022 no DataFrame 'df'.")
# Out:
# --- Análise para o ano de 2020 ---
# Município com a maior área desmatada em 2020:
# Nome: São Félix do Xingu
# Área Desmatada: 19873.40 km²
#
# --- Análise para o ano de 2022 ---
# Município com a maior área desmatada em 2022:
# Nome: São Félix do Xingu
# Área Desmatada: 20984.90 km²

# %%
import pandas as pd

# Filtra os dados para o ano de 2020
df_2020 = df[df['ano'] == 2020]

if not df_2020.empty:
    # Agrupa por município e soma o desmatamento, depois ordena
    top_10_municipios_2020 = df_2020.groupby('id_municipio_nome')['desmatado'].sum().nlargest(10).reset_index()
    top_10_municipios_2020.columns = ['Município', 'Área Desmatada (km²)'] # Renomeia colunas para clareza

    print("--- Top 10 Municípios com Maior Área Desmatada em 2020 ---")
    print(top_10_municipios_2020)
else:
    print("Não há dados de desmatamento para o ano de 2020 no DataFrame 'df'.")
# Out:
# --- Top 10 Municípios com Maior Área Desmatada em 2020 ---
#             Município  Área Desmatada (km²)
# 0  São Félix do Xingu               19873.4
# 1  Ribas do Rio Pardo               14054.5
# 2         Porto Velho               10893.5
# 3            Altamira               10515.0
# 4         Paranatinga                9245.3
# 5         Paragominas                8788.3
# 6              Marabá                8774.4
# 7   Novo Repartimento                8412.4
# 8         Três Lagoas                8357.1
# 9               Juara                8215.3

# %%
import pandas as pd

# Filtra os dados para o ano de 2022
df_2022 = df[df['ano'] == 2022]

if not df_2022.empty:
    # Agrupa por município e soma o desmatamento, depois ordena
    top_10_municipios_2022 = df_2022.groupby('id_municipio_nome')['desmatado'].sum().nlargest(10).reset_index()
    top_10_municipios_2022.columns = ['Município', 'Área Desmatada (km²)'] # Renomeia colunas para clareza

    print("\n--- Top 10 Municípios com Maior Área Desmatada em 2022 ---")
    print(top_10_municipios_2022)
else:
    print("Não há dados de desmatamento para o ano de 2022 no DataFrame 'df'.")
# Out:
# --- Top 10 Municípios com Maior Área Desmatada em 2022 ---
#             Município  Área Desmatada (km²)
# 0  São Félix do Xingu               20984.9
# 1  Ribas do Rio Pardo               14083.5
# 2         Porto Velho               12064.0
# 3            Altamira               11906.5
# 4         Paranatinga                9461.3
# 5              Marabá                8890.5
# 6         Paragominas                8866.5
# 7   Novo Repartimento                8712.3
# 8       São Desidério                8583.9
# 9               Juara                8384.0

# %%
import pandas as pd

# Agrupa por município e soma o desmatamento total, depois ordena
top_10_municipios_total = df.groupby('id_municipio_nome')['desmatado'].sum().nlargest(10).reset_index()
top_10_municipios_total.columns = ['Município', 'Área Desmatada Total (km²)'] # Renomeia colunas

print("\n--- Top 10 Municípios com Maior Área Desmatada Total (Todos os Anos) ---")
print(top_10_municipios_total)
# Out:
# --- Top 10 Municípios com Maior Área Desmatada Total (Todos os Anos) ---
#              Município  Área Desmatada Total (km²)
# 0   São Félix do Xingu                    388139.0
# 1   Ribas do Rio Pardo                    330075.9
# 2          Paragominas                    200780.2
# 3          Três Lagoas                    198296.9
# 4          Porto Velho                    195158.4
# 5          Paranatinga                    194410.7
# 6               Marabá                    190569.1
# 7                Juara                    182292.2
# 8             Altamira                    171573.7
# 9  Santana do Araguaia                    163263.7

# %%
import basedosdados as bd
import pandas as pd

billing_id = "trabalho-mc"

# Modificação da query SQL original para INCLUIR A COLUNA CORRETA DO ESTADO
query_df_com_estado = """
    SELECT
        dados.ano AS ano,
        dados.id_municipio AS id_municipio,
        diretorio_municipio.nome AS id_municipio_nome,
        diretorio_municipio.sigla_uf AS estado, -- CORRIGIDO AQUI: de sigla_estado para sigla_uf
        dados.bioma AS bioma,
        dados.area_total AS area_total,
        dados.desmatado AS desmatado,
        dados.vegetacao_natural AS vegetacao_natural,
        dados.nao_vegetacao_natural AS nao_vegetacao_natural,
        dados.hidrografia AS hidrografia
    FROM `basedosdados.br_inpe_prodes.municipio_bioma` AS dados
    LEFT JOIN `basedosdados.br_bd_diretorios_brasil.municipio` AS diretorio_municipio
        ON dados.id_municipio = diretorio_municipio.id_municipio
"""

# Recarregar o DataFrame 'df' com os dados originais e a nova coluna 'estado'
print("Recarregando o DataFrame 'df' com dados de desmatamento e a coluna 'estado'...")
df = bd.read_sql(query_df_com_estado, billing_project_id=billing_id)
print("DataFrame 'df' recarregado com sucesso com a coluna 'estado'.")

# Verificar as primeiras linhas e colunas para confirmar a nova coluna 'estado'
print("\nPrimeiras 5 linhas do DataFrame 'df' recarregado:")
print(df.head())
print("\nColunas do DataFrame 'df' recarregado:")
print(df.columns)
# Out:
# Recarregando o DataFrame 'df' com dados de desmatamento e a coluna 'estado'...
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
# DataFrame 'df' recarregado com sucesso com a coluna 'estado'.
#
# Primeiras 5 linhas do DataFrame 'df' recarregado:
#     ano id_municipio id_municipio_nome estado     bioma   area_total  \
# 0  2009      5102504           Cáceres     MT  Pantanal  17422.29079
# 1  2011      5102504           Cáceres     MT  Pantanal  17422.29079
# 2  2010      5102504           Cáceres     MT  Pantanal  17422.29079
# 3  2005      5102504           Cáceres     MT  Pantanal  17422.29079
# 4  2002      5102504           Cáceres     MT  Pantanal  17422.29079
#
#    desmatado  vegetacao_natural  nao_vegetacao_natural  hidrografia
# 0     3124.8            12616.5                    0.4       1680.6
# 1     3203.4            12537.9                    0.4       1680.6
# 2     3157.8            12583.5                    0.4       1680.6
# 3     2937.1            12804.2                    0.4       1680.6
# 4     2598.0            13143.3                    0.4       1680.6
#
# Colunas do DataFrame 'df' recarregado:
# Index(['ano', 'id_municipio', 'id_municipio_nome', 'estado', 'bioma',
#        'area_total', 'desmatado', 'vegetacao_natural', 'nao_vegetacao_natural',
#        'hidrografia'],
#       dtype='object')

# %%
# --- Top 10 Municípios com Maior Desmatamento em 2020 (com Estado) ---
print("\n--- Top 10 Municípios com Maior Área Desmatada em 2020 (com Estado) ---")
df_2020 = df[df['ano'] == 2020]

if not df_2020.empty:
    top_10_municipios_2020_estado = df_2020.groupby(['id_municipio_nome', 'estado'])['desmatado'].sum().nlargest(10).reset_index()
    top_10_municipios_2020_estado.columns = ['Município', 'Estado', 'Área Desmatada (km²)']
    print(top_10_municipios_2020_estado)
else:
    print("Não há dados de desmatamento para o ano de 2020 no DataFrame 'df'.")


# --- Top 10 Municípios com Maior Desmatamento em 2022 (com Estado) ---
print("\n--- Top 10 Municípios com Maior Área Desmatada em 2022 (com Estado) ---")
df_2022 = df[df['ano'] == 2022]

if not df_2022.empty:
    top_10_municipios_2022_estado = df_2022.groupby(['id_municipio_nome', 'estado'])['desmatado'].sum().nlargest(10).reset_index()
    top_10_municipios_2022_estado.columns = ['Município', 'Estado', 'Área Desmatada (km²)']
    print(top_10_municipios_2022_estado)
else:
    print("Não há dados de desmatamento para o ano de 2022 no DataFrame 'df'.")


# --- Top 10 Municípios com Maior Desmatamento Total (Todos os Anos, com Estado) ---
print("\n--- Top 10 Municípios com Maior Área Desmatada Total (Todos os Anos, com Estado) ---")
top_10_municipios_total_estado = df.groupby(['id_municipio_nome', 'estado'])['desmatado'].sum().nlargest(10).reset_index()
top_10_municipios_total_estado.columns = ['Município', 'Estado', 'Área Desmatada Total (km²)']
print(top_10_municipios_total_estado)
# Out:
# --- Top 10 Municípios com Maior Área Desmatada em 2020 (com Estado) ---
#             Município Estado  Área Desmatada (km²)
# 0  São Félix do Xingu     PA               19873.4
# 1  Ribas do Rio Pardo     MS               14054.5
# 2         Porto Velho     RO               10893.5
# 3            Altamira     PA               10515.0
# 4         Paranatinga     MT                9245.3
# 5         Paragominas     PA                8788.3
# 6              Marabá     PA                8774.4
# 7   Novo Repartimento     PA                8412.4
# 8         Três Lagoas     MS                8357.1
# 9               Juara     MT                8215.3
#
# --- Top 10 Municípios com Maior Área Desmatada em 2022 (com Estado) ---
#             Município Estado  Área Desmatada (km²)
# 0  São Félix do Xingu     PA               20984.9
# 1  Ribas do Rio Pardo     MS               14083.5
# 2         Porto Velho     RO               12064.0
# 3            Altamira     PA               11906.5
# 4         Paranatinga     MT                9461.3
# 5              Marabá     PA                8890.5
# 6         Paragominas     PA                8866.5
# 7   Novo Repartimento     PA                8712.3
# 8       São Desidério     BA                8583.9
# 9               Juara     MT                8384.0
#
# --- Top 10 Municípios com Maior Área Desmatada Total (Todos os Anos, com Estado) ---
#              Município Estado  Área Desmatada Total (km²)
# 0   São Félix do Xingu     PA                    388139.0
# 1   Ribas do Rio Pardo     MS                    330075.9
# 2          Paragominas     PA                    200780.2
# 3          Três Lagoas     MS                    198296.9
# 4          Porto Velho     RO                    195158.4
# 5          Paranatinga     MT                    194410.7
# 6               Marabá     PA                    190569.1
# 7                Juara     MT                    182292.2
# 8             Altamira     PA                    171573.7
# 9  Santana do Araguaia     PA                    163263.7

# %%
import pandas as pd

# --- 1. Desmatamento Total Geral (de todos os municípios e biomas - DataFrame 'df') ---
print("--- Desmatamento Total Geral (Dados por Município e Bioma - DataFrame 'df') ---")

if 'desmatado' in df.columns and not df.empty:
    total_desmatado_geral = df['desmatado'].sum()
    anos_geral = df['ano'].unique()
    primeiro_ano_geral = anos_geral.min()
    ultimo_ano_geral = anos_geral.max()

    print(f"Período dos dados: {primeiro_ano_geral} a {ultimo_ano_geral}")
    print(f"Área Total Desmatada (Geral): {total_desmatado_geral:.2f} km²")
else:
    print("O DataFrame 'df' não está carregado corretamente ou não contém a coluna 'desmatado'.")
    print("Por favor, certifique-se de ter executado a query_df_com_estado para recarregar o 'df'.")
# Out:
# --- Desmatamento Total Geral (Dados por Município e Bioma - DataFrame 'df') ---
# Período dos dados: 2000 a 2023
# Área Total Desmatada (Geral): 66943895.50 km²

# %%
import pandas as pd

# Certifique-se de que o DataFrame 'df' está carregado
# Se você o recarregou recentemente com a coluna 'estado', ele já estará pronto.
# Caso contrário, execute o bloco de código que recarrega 'df' com a 'query_df_com_estado'.

# Agrupa por ano e soma a área desmatada
desmatamento_por_ano_tabela = df.groupby('ano')['desmatado'].sum().reset_index()

# Renomeia as colunas para melhor clareza na tabela
desmatamento_por_ano_tabela.columns = ['Ano', 'Área Desmatada (km²)']

print("--- Área Desmatada Total por Ano ---")
print(desmatamento_por_ano_tabela)
# Out:
# --- Área Desmatada Total por Ano ---
#      Ano  Área Desmatada (km²)
# 0   2000             2249599.1
# 1   2001             2351135.6
# 2   2002             2424268.7
# 3   2003             2503687.9
# 4   2004             2580168.9
# 5   2005             2636961.2
# 6   2006             2681730.9
# 7   2007             2718411.2
# 8   2008             2756483.6
# 9   2009             2779940.5
# 10  2010             2803341.6
# 11  2011             2825862.3
# 12  2012             2845886.6
# 13  2013             2871441.1
# 14  2014             2895190.4
# 15  2015             2917402.4
# 16  2016             2937152.3
# 17  2017             2956064.4
# 18  2018             2975203.3
# 19  2019             2996696.3
# 20  2020             3019532.6
# 21  2021             3045620.1
# 22  2022             3073984.3
# 23  2023             3098130.2

# %%
import pandas as pd

# Certifique-se de que o DataFrame 'df' está carregado corretamente
# e que ele contém as colunas 'ano', 'id_municipio_nome', 'estado' e 'desmatado'.
# Se necessário, execute novamente o bloco de código que recarrega 'df'
# com a 'query_df_com_estado' (a que inclui a coluna 'estado').

print("--- Município e Estado com Maior Área Desmatada por Ano ---")

# Obtém todos os anos únicos presentes no DataFrame e os ordena
anos_unicos = sorted(df['ano'].unique())

# Lista para armazenar os resultados de cada ano
resultados_por_ano = []

for ano in anos_unicos:
    # Filtra o DataFrame para o ano atual
    df_do_ano = df[df['ano'] == ano]

    if not df_do_ano.empty:
        # Agrupa por município e estado, e soma o desmatamento para esse ano
        desmatamento_municipio_estado = df_do_ano.groupby(['id_municipio_nome', 'estado'])['desmatado'].sum().reset_index()

        # Encontra a linha com o maior valor de 'desmatado' para o ano atual
        if not desmatamento_municipio_estado.empty:
            municipio_mais_desmatado_no_ano = desmatamento_municipio_estado.loc[desmatamento_municipio_estado['desmatado'].idxmax()]

            resultados_por_ano.append({
                'Ano': ano,
                'Município': municipio_mais_desmatado_no_ano['id_municipio_nome'],
                'Estado': municipio_mais_desmatado_no_ano['estado'],
                'Área Desmatada (km²)': municipio_mais_desmatado_no_ano['desmatado']
            })
        else:
            # Caso não haja desmatamento registrado para nenhum município nesse ano (o que é raro, mas possível)
            resultados_por_ano.append({
                'Ano': ano,
                'Município': 'N/A',
                'Estado': 'N/A',
                'Área Desmatada (km²)': 0
            })
    else:
        # Caso o ano não exista no DataFrame
        resultados_por_ano.append({
            'Ano': ano,
            'Município': 'N/A',
            'Estado': 'N/A',
            'Área Desmatada (km²)': 0
        })

# Converte a lista de dicionários em um DataFrame para uma exibição tabular
tabela_anual_maior_desmatamento = pd.DataFrame(resultados_por_ano)

print(tabela_anual_maior_desmatamento)
# Out:
# --- Município e Estado com Maior Área Desmatada por Ano ---
#      Ano           Município Estado  Área Desmatada (km²)
# 0   2000  Ribas do Rio Pardo     MS               12593.9
# 1   2001  Ribas do Rio Pardo     MS               12812.7
# 2   2002  Ribas do Rio Pardo     MS               13031.5
# 3   2003  Ribas do Rio Pardo     MS               13291.7
# 4   2004  Ribas do Rio Pardo     MS               13551.9
# 5   2005  São Félix do Xingu     PA               13821.4
# 6   2006  São Félix do Xingu     PA               14585.2
# 7   2007  São Félix do Xingu     PA               15462.3
# 8   2008  São Félix do Xingu     PA               16221.1
# 9   2009  São Félix do Xingu     PA               16660.8
# 10  2010  São Félix do Xingu     PA               17010.4
# 11  2011  São Félix do Xingu     PA               17149.8
# 12  2012  São Félix do Xingu     PA               17317.5
# 13  2013  São Félix do Xingu     PA               17538.8
# 14  2014  São Félix do Xingu     PA               17691.6
# 15  2015  São Félix do Xingu     PA               17891.0
# 16  2016  São Félix do Xingu     PA               18205.9
# 17  2017  São Félix do Xingu     PA               18442.6
# 18  2018  São Félix do Xingu     PA               18719.7
# 19  2019  São Félix do Xingu     PA               19264.6
# 20  2020  São Félix do Xingu     PA               19873.4
# 21  2021  São Félix do Xingu     PA               20450.4
# 22  2022  São Félix do Xingu     PA               20984.9
# 23  2023  São Félix do Xingu     PA               21299.1

# %%
import plotly.express as px

# %%
import plotly.express as px
import pandas as pd

# Certifique-se de que o DataFrame 'df' está carregado corretamente
# com as colunas 'ano', 'estado' e 'desmatado'.
# Se necessário, execute o bloco de código que recarrega 'df' com a 'query_df_com_estado'
# antes de rodar este código.

# 1. Filtrar os dados para o período entre 2000 e 2023
df_periodo_2000_2023 = df[(df['ano'] >= 2000) & (df['ano'] <= 2023)]

if df_periodo_2000_2023.empty:
    print("Não há dados de desmatamento para o período entre 2000 e 2023 no DataFrame 'df'.")
else:
    # 2. Agrupar por estado e somar a área desmatada no período
    desmatamento_por_estado_total = df_periodo_2000_2023.groupby('estado')['desmatado'].sum().reset_index()
    desmatamento_por_estado_total.columns = ['Estado', 'Área Desmatada (km²)']

    # Opcional: Ordenar os estados pela área desmatada para que o gráfico fique mais claro
    desmatamento_por_estado_total = desmatamento_por_estado_total.sort_values(by='Área Desmatada (km²)', ascending=True)

    # 3. Criar o gráfico de barras horizontais para Estados
    fig_estado_barras = px.bar(desmatamento_por_estado_total,
                               x='Área Desmatada (km²)',
                               y='Estado',
                               title='Área Desmatada por Estado (2000-2023)',
                               orientation='h', # Define as barras como horizontais
                               text='Área Desmatada (km²)', # Exibe o valor da área desmatada na barra
                               height=600) # Ajusta a altura do gráfico para melhor visualização

    # Ajustar o formato do texto para ter duas casas decimais e posicioná-lo fora da barra
    fig_estado_barras.update_traces(texttemplate='%{text:.2f}', textposition='outside')
    fig_estado_barras.update_layout(uniformtext_minsize=8, uniformtext_mode='hide') # Esconder texto se for muito pequeno

    fig_estado_barras.show()

# %%
import basedosdados as bd

billing_id = "trabalho-mc"

query = """
  SELECT
    dados.ano as ano,
    dados.sigla_uf AS sigla_uf,
    diretorio_sigla_uf.nome AS sigla_uf_nome,
    dados.id_municipio AS id_municipio,
    diretorio_id_municipio.nome AS id_municipio_nome,
    dados.tipo_rebanho as tipo_rebanho,
    dados.quantidade as quantidade
FROM `basedosdados.br_ibge_ppm.efetivo_rebanhos` AS dados
LEFT JOIN (SELECT DISTINCT sigla,nome  FROM `basedosdados.br_bd_diretorios_brasil.uf`) AS diretorio_sigla_uf
    ON dados.sigla_uf = diretorio_sigla_uf.sigla
LEFT JOIN (SELECT DISTINCT id_municipio,nome  FROM `basedosdados.br_bd_diretorios_brasil.municipio`) AS diretorio_id_municipio
    ON dados.id_municipio = diretorio_id_municipio.id_municipio
"""

bd.read_sql(query = query, billing_project_id = "trabalho-mc")
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
#           ano sigla_uf     sigla_uf_nome id_municipio id_municipio_nome  \
# 0        1989       AC              Acre      1200054      Assis Brasil
# 1        1989       AC              Acre      1200104         Brasiléia
# 2        1989       AC              Acre      1200203   Cruzeiro do Sul
# 3        1989       AC              Acre      1200302             Feijó
# 4        1989       AC              Acre      1200336       Mâncio Lima
# ...       ...      ...               ...          ...               ...
# 1368139  2006       GO             Goiás      5222005        Vianópolis
# 1368140  2006       GO             Goiás      5222054    Vicentinópolis
# 1368141  2006       GO             Goiás      5222203          Vila Boa
# 1368142  2006       GO             Goiás      5222302     Vila Propício
# 1368143  2006       DF  Distrito Federal      5300108          Brasília
#
#                   tipo_rebanho  quantidade
# 0                       Bovino        1859
# 1                       Bovino       58810
# 2                       Bovino       18608
# 3                       Bovino       24200
# 4                       Bovino        2027
# ...                        ...         ...
# 1368139  Galináceos - galinhas       12100
# 1368140  Galináceos - galinhas        9740
# 1368141  Galináceos - galinhas        2350
# 1368142  Galináceos - galinhas       10000
# 1368143  Galináceos - galinhas     1435323
#
# [1368144 rows x 7 columns]

# %%
import numpy as np

# %%
query = """
SELECT * FROM `basedosdados.br_ibge_ppm.efetivo_rebanhos`
WHERE ano BETWEEN 2000 AND 2023;
"""

df_ppm = bd.read_sql(query, billing_project_id="trabalho-mc")
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
df_ppm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753689 entries, 0 to 753688
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ano           753689 non-null  Int64
#  1   sigla_uf      753689 non-null  object
#  2   id_municipio  753689 non-null  object
#  3   tipo_rebanho  753689 non-null  object
#  4   quantidade    753689 non-null  Int64
# dtypes: Int64(2), object(3)
# memory usage: 30.2+ MB

# %%
df_ppm.head()
# Out:
#     ano sigla_uf id_municipio tipo_rebanho  quantidade
# 0  2002       AC      1200013       Bovino      101926
# 1  2002       AC      1200054       Bovino       13700
# 2  2002       AC      1200104       Bovino      149112
# 3  2002       AC      1200138       Bovino      148607
# 4  2002       AC      1200179       Bovino       78826

# %%
df_ppm["tipo_rebanho"].unique()
# Out:
# array(['Bovino', 'Equino', 'Caprino', 'Bubalino', 'Codornas',
#        'Suíno - total', 'Galináceos - galinhas',
#        'Suíno - matrizes de suínos'], dtype=object)

# %%
import basedosdados as bd

billing_id = "trabalho-mc"

query = """
  SELECT
    dados.ano as ano,
    dados.sigla_uf AS sigla_uf,
    diretorio_sigla_uf.nome AS sigla_uf_nome,
    dados.id_municipio AS id_municipio,
    diretorio_id_municipio.nome AS id_municipio_nome,
    dados.tipo_rebanho as tipo_rebanho,
    dados.quantidade as quantidade
FROM `basedosdados.br_ibge_ppm.efetivo_rebanhos` AS dados
LEFT JOIN (SELECT DISTINCT sigla,nome  FROM `basedosdados.br_bd_diretorios_brasil.uf`) AS diretorio_sigla_uf
    ON dados.sigla_uf = diretorio_sigla_uf.sigla
LEFT JOIN (SELECT DISTINCT id_municipio,nome  FROM `basedosdados.br_bd_diretorios_brasil.municipio`) AS diretorio_id_municipio
    ON dados.id_municipio = diretorio_id_municipio.id_municipio
"""

df = bd.read_sql(query = query, billing_project_id = "trabalho-mc")

print(df.head())
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
#     ano sigla_uf sigla_uf_nome id_municipio id_municipio_nome tipo_rebanho  \
# 0  1989       AC          Acre      1200054      Assis Brasil       Bovino
# 1  1989       AC          Acre      1200104         Brasiléia       Bovino
# 2  1989       AC          Acre      1200203   Cruzeiro do Sul       Bovino
# 3  1989       AC          Acre      1200302             Feijó       Bovino
# 4  1989       AC          Acre      1200336       Mâncio Lima       Bovino
#
#    quantidade
# 0        1859
# 1       58810
# 2       18608
# 3       24200
# 4        2027

# %%
import basedosdados as bd
import pandas as pd # Importar pandas para manipulação do DataFrame

# Seu código para carregar os dados
billing_id = "trabalho-mc"
query = """
  SELECT
    dados.ano as ano,
    dados.sigla_uf AS sigla_uf,
    diretorio_sigla_uf.nome AS sigla_uf_nome,
    dados.id_municipio AS id_municipio,
    diretorio_id_municipio.nome AS id_municipio_nome,
    dados.tipo_rebanho as tipo_rebanho,
    dados.quantidade as quantidade
FROM `basedosdados.br_ibge_ppm.efetivo_rebanhos` AS dados
LEFT JOIN (SELECT DISTINCT sigla,nome  FROM `basedosdados.br_bd_diretorios_brasil.uf`) AS diretorio_sigla_uf
    ON dados.sigla_uf = diretorio_sigla_uf.sigla
LEFT JOIN (SELECT DISTINCT id_municipio,nome  FROM `basedosdados.br_bd_diretorios_brasil.municipio`) AS diretorio_id_municipio
    ON dados.id_municipio = diretorio_id_municipio.id_municipio
"""

df = bd.read_sql(query = query, billing_project_id = "trabalho-mc")

# Salvar o DataFrame como CSV
nome_arquivo_csv = "rebanhos_efetivos.csv"
df.to_csv(nome_arquivo_csv, index=False) # index=False evita salvar o índice do DataFrame como uma coluna
print(f"Dados salvos em {nome_arquivo_csv}")
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
# Dados salvos em rebanhos_efetivos.csv

# %%
import pandas as pd

# 1. Carregar os DataFrames
try:
    df_rebanhos = pd.read_csv("rebanhos_efetivos.csv")
    print("DataFrame 'df_rebanhos' carregado com sucesso.")
except FileNotFoundError:
    print("Erro: O arquivo 'rebanhos_efetivos.csv' não foi encontrado. Certifique-se de que ele está no mesmo diretório do script.")
    exit() # Sai do script se o arquivo principal não for encontrado

try:
    df_prodes = pd.read_csv("dados_prodes_municipio_bioma.csv")
    print("DataFrame 'df_prodes' carregado com sucesso.")
except FileNotFoundError:
    print("Erro: O arquivo 'dados_prodes_municipio_bioma.csv' não foi encontrado. Verifique o nome e o caminho.")
    exit() # Sai do script se o arquivo PRODES não for encontrado


print("\nPrimeiras linhas de df_rebanhos:")
print(df_rebanhos.head())

print("\nPrimeiras linhas de df_prodes (verifique se as colunas estão corretas):")
print(df_prodes.head())

# Verifique as colunas disponíveis em ambos os DataFrames
print("\nColunas em df_rebanhos:", df_rebanhos.columns.tolist())
print("Colunas em df_prodes:", df_prodes.columns.tolist())


# 2. e 3. Realizar a junção (merge) dos DataFrames

# Assumindo que a coluna chave é 'id_municipio' e você quer cruzar por 'ano' também
# Se o nome da coluna de ID do município no df_prodes for diferente, ajuste 'id_municipio_prodes'
# Exemplo: df_prodes.rename(columns={'coluna_id_municipio_no_prodes': 'id_municipio'}, inplace=True)
# Ou: 'left_on' e 'right_on' no merge

coluna_id_municipio_prodes = 'id_municipio' # Ajuste aqui se o nome da coluna for diferente no seu CSV PRODES
coluna_ano_prodes = 'ano' # Ajuste aqui se o nome da coluna for diferente no seu CSV PRODES

# Verificando se as colunas esperadas existem em df_prodes
if coluna_id_municipio_prodes not in df_prodes.columns:
    print(f"\nAVISO: A coluna '{coluna_id_municipio_prodes}' não foi encontrada em 'df_prodes'. Por favor, verifique o nome da coluna no seu arquivo 'dados_prodes_municipio_bioma.csv' e ajuste o código.")
    # Tentativa de ajuste comum: se o nome da coluna for 'id_municipio_geocodigo' ou 'id_municipio_6'
    if 'id_municipio_geocodigo' in df_prodes.columns:
        print("Trocando para 'id_municipio_geocodigo'.")
        coluna_id_municipio_prodes = 'id_municipio_geocodigo'
    elif 'id_municipio_6' in df_prodes.columns:
        print("Trocando para 'id_municipio_6'.")
        coluna_id_municipio_prodes = 'id_municipio_6'
    else:
        print("Não foi possível encontrar uma coluna de ID de município comum automaticamente. Por favor, ajuste manualmente.")
        exit()

if coluna_ano_prodes not in df_prodes.columns:
    print(f"\nAVISO: A coluna '{coluna_ano_prodes}' não foi encontrada em 'df_prodes'. Por favor, verifique o nome da coluna no seu arquivo 'dados_prodes_municipio_bioma.csv' e ajuste o código.")
    # Se 'ano' não existe no PRODES, você pode optar por não cruzar por ano, ou tentar outra coluna
    # Por enquanto, vamos parar se 'ano' for a chave esperada.
    exit()

# O 'how='inner'' garante que apenas as linhas que têm correspondência em AMBOS os DataFrames serão incluídas.
# 'on' especifica as colunas para junção.
df_cruzado = pd.merge(df_rebanhos, df_prodes,
                      left_on=['ano', 'id_municipio'],
                      right_on=[coluna_ano_prodes, coluna_id_municipio_prodes],
                      how='inner')

print("\nDataFrame cruzado ('df_cruzado'):")
print(df_cruzado.head())

print(f"\nDimensões do DataFrame de rebanhos: {df_rebanhos.shape}")
print(f"Dimensões do DataFrame PRODES: {df_prodes.shape}")
print(f"Dimensões do DataFrame cruzado: {df_cruzado.shape}")

# Opcional: Salvar o DataFrame cruzado
nome_arquivo_cruzado = "dados_rebanhos_prodes_cruzado.csv"
df_cruzado.to_csv(nome_arquivo_cruzado, index=False)
print(f"\nDados cruzados salvos em {nome_arquivo_cruzado}")
# Out:
# DataFrame 'df_rebanhos' carregado com sucesso.
# DataFrame 'df_prodes' carregado com sucesso.
#
# Primeiras linhas de df_rebanhos:
#     ano sigla_uf sigla_uf_nome  id_municipio id_municipio_nome tipo_rebanho  \
# 0  1989       AC          Acre       1200054      Assis Brasil       Bovino
# 1  1989       AC          Acre       1200104         Brasiléia       Bovino
# 2  1989       AC          Acre       1200203   Cruzeiro do Sul       Bovino
# 3  1989       AC          Acre       1200302             Feijó       Bovino
# 4  1989       AC          Acre       1200336       Mâncio Lima       Bovino
#
#    quantidade
# 0        1859
# 1       58810
# 2       18608
# 3       24200
# 4        2027
#
# Primeiras linhas de df_prodes (verifique se as colunas estão corretas):
#     ano  id_municipio id_municipio_nome     bioma   area_total  desmatado  \
# 0  2009       5102504           Cáceres  Pantanal  17422.29079     3124.8
# 1  2011       5102504           Cáceres  Pantanal  17422.29079     3203.4
# 2  2010       5102504           Cáceres  Pantanal  17422.29079     3157.8
# 3  2005       5102504           Cáceres  Pantanal  17422.29079     2937.1
# 4  2002       5102504           Cáceres  Pantanal  17422.29079     2598.0
#
#    vegetacao_natural  nao_vegetacao_natural  hidrografia
# 0            12616.5                    0.4       1680.6
# 1            12537.9                    0.4       1680.6
# 2            12583.5                    0.4       1680.6
# 3            12804.2                    0.4       1680.6
# 4            13143.3                    0.4       1680.6
#
# Colunas em df_rebanhos: ['ano', 'sigla_uf', 'sigla_uf_nome', 'id_municipio', 'id_municipio_nome', 'tipo_rebanho', 'quantidade']
# Colunas em df_prodes: ['ano', 'id_municipio', 'id_municipio_nome', 'bioma', 'area_total', 'desmatado', 'vegetacao_natural', 'nao_vegetacao_natural', 'hidrografia']
#
# DataFrame cruzado ('df_cruzado'):
#     ano sigla_uf sigla_uf_nome  id_municipio id_municipio_nome_x tipo_rebanho  \
# 0  2013       AC          Acre       1200013          Acrelândia       Bovino
# 1  2013       AC          Acre       1200054        Assis Brasil       Bovino
# 2  2013       AC          Acre       1200104           Brasiléia       Bovino
# 3  2013       AC          Acre       1200138              Bujari       Bovino
# 4  2013       AC          Acre       1200179            Capixaba       Bovino
#
#    quantidade id_municipio_nome_y     bioma  area_total  desmatado  \
# 0      176318          Acrelândia  Amazônia  1819.49772     1078.4
# 1       39318        Assis Brasil  Amazônia  4979.44236      252.5
# 2      202584           Brasiléia  Amazônia  3927.09573     1281.5
# 3      206059              Bujari  Amazônia  3017.16052     1175.6
# 4      147187            Capixaba  Amazônia  1716.90194      848.0
#
#    vegetacao_natural  nao_vegetacao_natural  hidrografia
# 0              741.1                    0.0          0.0
# 1             4726.6                    0.3          0.0
# 2             2645.4                    0.0          0.2
# 3             1841.4                    0.0          0.2
# 4              868.9                    0.0          0.0
#
# Dimensões do DataFrame de rebanhos: (1368144, 7)
# Dimensões do DataFrame PRODES: (156864, 9)
# Dimensões do DataFrame cruzado: (886605, 14)
#
# Dados cruzados salvos em dados_rebanhos_prodes_cruzado.csv

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\laism\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.11.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: packaging in c:\users\laism\anaconda3\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\laism\anaconda3\lib\site-packages (from geopandas) (2.2.3)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.1-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laism\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laism\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laism\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\laism\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.4.26)
# Requirement already satisfied: six>=1.5 in c:\users\laism\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.16.0)
# Downloading geopandas-1.1.0-py3-none-any.whl (338 kB)
# Downloading pyogrio-0.11.0-cp312-cp312-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    ---- ----------------------------------- 2.4/19.2 MB 13.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 5.2/19.2 MB 13.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 7.9/19.2 MB 13.2 MB/s eta 0:00:01
#    -------------------- ------------------- 10.0/19.2 MB 12.7 MB/s eta 0:00:01
#    ------------------------ --------------- 11.5/19.2 MB 11.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 13.6/19.2 MB 11.0 MB/s eta 0:00:01
#    -------------------------------- ------- 15.7/19.2 MB 10.9 MB/s eta 0:00:01
#    -------------------------------------- - 18.4/19.2 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 10.7 MB/s eta 0:00:00
# Downloading pyproj-3.7.1-cp312-cp312-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------- ----------------------- 2.6/6.3 MB 13.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.3 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 12.4 MB/s eta 0:00:00
# Downloading shapely-2.1.1-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.6 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.1.0 pyogrio-0.11.0 pyproj-3.7.1 shapely-2.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.19.7-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\laism\anaconda3\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\laism\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\laism\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\laism\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\laism\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laism\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laism\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laism\anaconda3\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laism\anaconda3\lib\site-packages (from requests->folium) (2025.4.26)
# Downloading folium-0.19.7-py2.py3-none-any.whl (112 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.8.1 folium-0.19.7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn as sns
# Out:
# Requirement already satisfied: seaborn in c:\users\laism\anaconda3\lib\site-packages (0.13.2)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
pip install matplotlib.pyplot as plt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot

# %%
pip install geobr
# Out:
# Collecting geobr
#   Downloading geobr-0.2.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: geopandas<=1.1,>=1.0.0 in c:\users\laism\anaconda3\lib\site-packages (from geobr) (1.1.0)
# Collecting shapely<=2.1.0,>=1.7.0 (from geobr)
#   Downloading shapely-2.1.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in c:\users\laism\anaconda3\lib\site-packages (from geobr) (2.32.3)
# Requirement already satisfied: lxml<6.0.0,>=5.1.0 in c:\users\laism\anaconda3\lib\site-packages (from geobr) (5.2.1)
# Collecting html5lib==1.1 (from geobr)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.9 in c:\users\laism\anaconda3\lib\site-packages (from html5lib==1.1->geobr) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\laism\anaconda3\lib\site-packages (from html5lib==1.1->geobr) (0.5.1)
# Requirement already satisfied: numpy>=1.24 in c:\users\laism\anaconda3\lib\site-packages (from geopandas<=1.1,>=1.0.0->geobr) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\laism\anaconda3\lib\site-packages (from geopandas<=1.1,>=1.0.0->geobr) (0.11.0)
# Requirement already satisfied: packaging in c:\users\laism\anaconda3\lib\site-packages (from geopandas<=1.1,>=1.0.0->geobr) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\laism\anaconda3\lib\site-packages (from geopandas<=1.1,>=1.0.0->geobr) (2.2.3)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\laism\anaconda3\lib\site-packages (from geopandas<=1.1,>=1.0.0->geobr) (3.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.25.1->geobr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.25.1->geobr) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.25.1->geobr) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laism\anaconda3\lib\site-packages (from requests<3.0.0,>=2.25.1->geobr) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laism\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas<=1.1,>=1.0.0->geobr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laism\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas<=1.1,>=1.0.0->geobr) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laism\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas<=1.1,>=1.0.0->geobr) (2023.3)
# Downloading geobr-0.2.2-py3-none-any.whl (37 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading shapely-2.1.0-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 8.4 MB/s eta 0:00:00
# Installing collected packages: shapely, html5lib, geobr
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.1.1
#     Uninstalling shapely-2.1.1:
#       Successfully uninstalled shapely-2.1.1
# Successfully installed geobr-0.2.2 html5lib-1.1 shapely-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
print("Folium está acessível neste ambiente!")
# Out:
# Folium está acessível neste ambiente!

# %%
import geobr
print("Testando conexão e download com geobr...")
try:
    # Tente um ano diferente, como 2019 ou 2021, ou o mais recente que pode ser 2022
    temp_gdf = geobr.read_municipality(code_muni="all", year=2019) 
    print(f"Sucesso! Carregou {len(temp_gdf)} municípios para o ano 2019.")
    print("Colunas disponíveis no GeoDataFrame do geobr:", temp_gdf.columns.tolist())
    # Se funcionar, você pode tentar com year=2020 ou year=2021 novamente.

except Exception as e:
    print(f"Falha ao carregar com geobr: {e}")
    print("Verifique sua conexão com a internet.")
    print("Se persistir, pode ser um problema com as dependências do geobr ou o servidor de dados.")
# Out:
# Testando conexão e download com geobr...
# Sucesso! Carregou 5572 municípios para o ano 2019.
# Colunas disponíveis no GeoDataFrame do geobr: ['code_muni', 'name_muni', 'code_state', 'abbrev_state', 'name_state', 'code_region', 'name_region', 'geometry']

# %%
# --- 3. Adicionar dados geográficos dos municípios usando geobr ---
try:
    # Mude o ano aqui para 2019, que você sabe que funciona
    ano_malha = 2019 # <--- ALtere para 2019
    print(f"\nTentando carregar geometrias dos municípios para o ano {ano_malha} usando geobr...")
    gdf_municipios = geobr.read_municipality(code_muni="all", year=ano_malha)
    print("GeoDataFrame de municípios carregado com sucesso via geobr.")
    print("Colunas do GeoDataFrame de municípios (gdf_municipios):", gdf_municipios.columns.tolist())

    if 'code_muni' in gdf_municipios.columns:
        gdf_municipios = gdf_municipios.rename(columns={'code_muni': 'id_municipio'})
    
    # Esta linha já está corrigida para remover o '.0'
    gdf_municipios['id_municipio'] = gdf_municipios['id_municipio'].astype(str).str.replace(r'\.0$', '', regex=True).str.zfill(7)
    print(f"Exemplo de id_municipio em gdf_municipios (após zfill e replace): {gdf_municipios['id_municipio'].head()}")


except Exception as e:
    print(f"\nERRO ao carregar geometrias dos municípios com geobr: {e}")
    print("Certifique-se de que a biblioteca 'geobr' está instalada e que o ano especificado é válido.")
    exit()
# Out:
# Tentando carregar geometrias dos municípios para o ano 2019 usando geobr...
# GeoDataFrame de municípios carregado com sucesso via geobr.
# Colunas do GeoDataFrame de municípios (gdf_municipios): ['code_muni', 'name_muni', 'code_state', 'abbrev_state', 'name_state', 'code_region', 'name_region', 'geometry']
# Exemplo de id_municipio em gdf_municipios (após zfill e replace): 0    1100015
# 1    1100023
# 2    1100031
# 3    1100049
# 4    1100056
# Name: id_municipio, dtype: object

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\laism\anaconda3\lib\site-packages (0.19.7)
# Requirement already satisfied: branca>=0.6.0 in c:\users\laism\anaconda3\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\laism\anaconda3\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\laism\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\laism\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\laism\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\laism\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laism\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laism\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laism\anaconda3\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laism\anaconda3\lib\site-packages (from requests->folium) (2025.4.26)

# %%
import folium
import json # Para trabalhar com GeoJSON, embora aqui vamos criar dados simples
import random # Para simular alguns pontos de dados aleatórios

# --- 1. Definir as coordenadas centrais do mapa (Brasil ou uma região específica) ---
# Vamos centrar o mapa no centro-oeste do Brasil, uma região com avanço da agropecuária e desmatamento
# Coordenadas aproximadas para Mato Grosso/Goiás
center_latitude = -15.0
center_longitude = -55.0

m = folium.Map(location=[center_latitude, center_longitude], zoom_start=5, tiles='OpenStreetMap')

# --- 2. Dados Simulados de Áreas de Maior Desmatamento ---
# Representaremos áreas de desmatamento como polígonos vermelhos
# Estas são coordenadas fictícias para fins de demonstração
desmatamento_areas = [
    {
        "nome": "Área Desmatada 1 (Amazônia)",
        "coordenadas": [
            [-8.0, -60.0],
            [-8.5, -60.0],
            [-8.5, -59.5],
            [-8.0, -59.5],
            [-8.0, -60.0] # Fechar o polígono
        ],
        "descricao": "Desmatamento recente para pastagem."
    },
    {
        "nome": "Área Desmatada 2 (Cerrado)",
        "coordenadas": [
            [-13.0, -47.0],
            [-13.2, -47.0],
            [-13.2, -46.8],
            [-13.0, -46.8],
            [-13.0, -47.0]
        ],
        "descricao": "Expansão de monoculturas."
    }
]

# Adicionar as áreas de desmatamento ao mapa
for area in desmatamento_areas:
    folium.Polygon(
        locations=area["coordenadas"],
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.6,
        popup=f"<b>{area['nome']}</b><br>{area['descricao']}"
    ).add_to(m)


# --- 3. Dados Simulados de Áreas com Avanço da Agropecuária ---
# Representaremos o avanço da agropecuária com polígonos verdes ou laranjas, ou marcadores de círculo
# Vamos usar círculos grandes para indicar áreas de avanço agropecuário
agropecuaria_areas = [
    {
        "nome": "Fazenda Grãos do Cerrado",
        "coordenadas": [-17.5, -50.0], # Latitude, Longitude
        "raio": 20000, # Raio em metros para o círculo
        "cor": "orange",
        "descricao": "Grandes plantações de soja e milho."
    },
    {
        "nome": "Pecuária Expansiva (Pantanal)",
        "coordenadas": [-19.0, -57.0],
        "raio": 25000,
        "cor": "green",
        "descricao": "Aumento de áreas de pastagem."
    }
]

# Adicionar as áreas de agropecuária ao mapa
for area in agropecuaria_areas:
    folium.Circle(
        location=area["coordenadas"],
        radius=area["raio"],
        color=area["cor"],
        fill=True,
        fill_color=area["cor"],
        fill_opacity=0.4,
        popup=f"<b>{area['nome']}</b><br>{area['descricao']}"
    ).add_to(m)

# --- 4. Adicionar um controle de camadas (opcional, mas muito útil) ---
# Isso permite ao usuário ligar/desligar as camadas de desmatamento e agropecuária
# (Para este exemplo simples, as camadas são fixas, mas em um cenário real com grupos de GeoJSONs, isso seria ideal)
folium.LayerControl().add_to(m)


# --- 5. Salvar o mapa em um arquivo HTML (para compartilhar ou visualizar fora do Jupyter) ---
map_filename = 'mapa_desmatamento_agropecuaria.html'
m.save(map_filename)
print(f"Mapa salvo como '{map_filename}'")

# --- 6. Exibir o mapa no Jupyter Notebook ---
m
# Out:
# Mapa salvo como 'mapa_desmatamento_agropecuaria.html'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fd052068bd504011d9a94b23c7ec314 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fd052068bd504011d9a94b23c7ec314&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fd052068bd504011d9a94b23c7ec314 = L.map(
#                 &quot;map_9fd052068bd504011d9a94b23c7ec314&quot;,
#                 {
#                     center: [-15.0, -55.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fac8a4516b98ddb245a0f85e452d34b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0fac8a4516b98ddb245a0f85e452d34b.addTo(map_9fd052068bd504011d9a94b23c7ec314);
#
#
#             var polygon_f96e52a5d462d341810a00a9f4a98e51 = L.polygon(
#                 [[-8.0, -60.0], [-8.5, -60.0], [-8.5, -59.5], [-8.0, -59.5], [-8.0, -60.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fd052068bd504011d9a94b23c7ec314);
#
#
#         var popup_80fd2a49a309e120c3c0a8f4df30c73a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86115e99965d0719587cc5d66f5fd992 = $(`&lt;div id=&quot;html_86115e99965d0719587cc5d66f5fd992&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Área Desmatada 1 (Amazônia)&lt;/b&gt;&lt;br&gt;Desmatamento recente para pastagem.&lt;/div&gt;`)[0];
#                 popup_80fd2a49a309e120c3c0a8f4df30c73a.setContent(html_86115e99965d0719587cc5d66f5fd992);
#
#
#
#         polygon_f96e52a5d462d341810a00a9f4a98e51.bindPopup(popup_80fd2a49a309e120c3c0a8f4df30c73a)
#         ;
#
#
#
#
#             var polygon_53aa80058cb261fbe2e1d0e9eb9fc848 = L.polygon(
#                 [[-13.0, -47.0], [-13.2, -47.0], [-13.2, -46.8], [-13.0, -46.8], [-13.0, -47.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fd052068bd504011d9a94b23c7ec314);
#
#
#         var popup_348644e52ad2d6a57d46690fa5b78874 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_559dba95aa405d4e987aa81ed486ceac = $(`&lt;div id=&quot;html_559dba95aa405d4e987aa81ed486ceac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Área Desmatada 2 (Cerrado)&lt;/b&gt;&lt;br&gt;Expansão de monoculturas.&lt;/div&gt;`)[0];
#                 popup_348644e52ad2d6a57d46690fa5b78874.setContent(html_559dba95aa405d4e987aa81ed486ceac);
#
#
#
#         polygon_53aa80058cb261fbe2e1d0e9eb9fc848.bindPopup(popup_348644e52ad2d6a57d46690fa5b78874)
#         ;
#
#
#
#
#             var circle_98b74615b7b2589e534172f3f8e82590 = L.circle(
#                 [-17.5, -50.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9fd052068bd504011d9a94b23c7ec314);
#
#
#         var popup_046e54fde371684dc625cfea6811ca6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c6eba162d1abab0d1b8dff2c4e0c605 = $(`&lt;div id=&quot;html_8c6eba162d1abab0d1b8dff2c4e0c605&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Fazenda Grãos do Cerrado&lt;/b&gt;&lt;br&gt;Grandes plantações de soja e milho.&lt;/div&gt;`)[0];

# %%
import folium

# --- 1. Definir as coordenadas centrais do mapa ---
center_latitude = -15.0
center_longitude = -55.0

m = folium.Map(location=[center_latitude, center_longitude], zoom_start=5, tiles='OpenStreetMap')

# --- 2. Dados Simulados de Áreas de Maior Desmatamento ---
# Representaremos áreas de desmatamento como polígonos vermelhos
desmatamento_areas = [
    {
        "nome": "Área Desmatada 1 (Amazônia)",
        "coordenadas": [
            [-8.0, -60.0],
            [-8.5, -60.0],
            [-8.5, -59.5],
            [-8.0, -59.5],
            [-8.0, -60.0] # Fechar o polígono
        ],
        "descricao": "Desmatamento recente para pastagem."
    },
    {
        "nome": "Área Desmatada 2 (Cerrado)",
        "coordenadas": [
            [-13.0, -47.0],
            [-13.2, -47.0],
            [-13.2, -46.8],
            [-13.0, -46.8],
            [-13.0, -47.0]
        ],
        "descricao": "Expansão de monoculturas."
    }
]

print("Adicionando polígonos de desmatamento...") # Mensagem de depuração
# Adicionar as áreas de desmatamento ao mapa usando folium.Polygon
for area_desmatamento in desmatamento_areas:
    folium.Polygon(
        locations=area_desmatamento["coordenadas"],
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.6,
        popup=f"<b>{area_desmatamento['nome']}</b><br>{area_desmatamento['descricao']}"
    ).add_to(m)
print("Polígonos de desmatamento adicionados.")


# --- 3. Dados Simulados de Áreas com Avanço da Agropecuária ---
# Representaremos o avanço da agropecuária com círculos laranjas
agropecuaria_areas = [
    {
        "nome": "Fazenda Grãos do Cerrado",
        "coordenadas": [-17.5, -50.0], # Latitude, Longitude para o CENTRO do círculo
        "raio": 20000, # Raio em metros para o círculo
        "cor": "orange",
        "descricao": "Grandes plantações de soja e milho."
    },
    {
        "nome": "Pecuária Expansiva (Pantanal)",
        "coordenadas": [-19.0, -57.0], # Latitude, Longitude para o CENTRO do círculo
        "raio": 25000,
        "cor": "orange",
        "descricao": "Aumento de áreas de pastagem."
    }
]

print("Adicionando círculos de agropecuária...") # Mensagem de depuração
# Adicionar as áreas de agropecuária ao mapa usando folium.Circle
for area_agropecuaria in agropecuaria_areas:
    folium.Circle(
        location=area_agropecuaria["coordenadas"],
        radius=area_agropecuaria["raio"],
        color=area_agropecuaria["cor"],
        fill=True,
        fill_color=area_agropecuaria["cor"],
        fill_opacity=0.4,
        popup=f"<b>{area_agropecuaria['nome']}</b><br>{area_agropecuaria['descricao']}"
    ).add_to(m)
print("Círculos de agropecuária adicionados.")


# --- 4. Adicionar a Legenda Explícita usando HTML ---
legend_html = """
     <div style="position: fixed;
     bottom: 50px; left: 50px; width: 180px; height: 110px;
     border:2px solid grey; z-index:9999; font-size:14px;
     background-color:white; opacity:0.9;">
       &nbsp; <b>Legenda</b> <br>
       &nbsp; <i style="background:red; width:20px; height:20px; display:inline-block; border:1px solid grey;"></i> Desmatamento <br>
       &nbsp; <i style="background:orange; width:20px; height:20px; display:inline-block; border:1px solid grey;"></i> Avanço Agropecuária <br>
     </div>
     """

m.get_root().html.add_child(folium.Element(legend_html))

# --- 5. Salvar e Exibir o mapa ---
map_filename = 'mapa_desmatamento_agropecuaria_com_legenda_corrigido.html'
m.save(map_filename)
print(f"Mapa salvo com legenda como '{map_filename}'")

m
# Out:
# Adicionando polígonos de desmatamento...
# Polígonos de desmatamento adicionados.
# Adicionando círculos de agropecuária...
# Círculos de agropecuária adicionados.
# Mapa salvo com legenda como 'mapa_desmatamento_agropecuaria_com_legenda_corrigido.html'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acb353ae6e106787cf5a880d39f17a5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;div style=&quot;position: fixed;
#      bottom: 50px; left: 50px; width: 180px; height: 110px;
#      border:2px solid grey; z-index:9999; font-size:14px;
#      background-color:white; opacity:0.9;&quot;&gt;
#        &amp;nbsp; &lt;b&gt;Legenda&lt;/b&gt; &lt;br&gt;
#        &amp;nbsp; &lt;i style=&quot;background:red; width:20px; height:20px; display:inline-block; border:1px solid grey;&quot;&gt;&lt;/i&gt; Desmatamento &lt;br&gt;
#        &amp;nbsp; &lt;i style=&quot;background:orange; width:20px; height:20px; display:inline-block; border:1px solid grey;&quot;&gt;&lt;/i&gt; Avanço Agropecuária &lt;br&gt;
#      &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acb353ae6e106787cf5a880d39f17a5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acb353ae6e106787cf5a880d39f17a5a = L.map(
#                 &quot;map_acb353ae6e106787cf5a880d39f17a5a&quot;,
#                 {
#                     center: [-15.0, -55.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93b0634ab94d0bd48664775ffe681363 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_93b0634ab94d0bd48664775ffe681363.addTo(map_acb353ae6e106787cf5a880d39f17a5a);
#
#
#             var polygon_17388cdc1e887db21dc0df5e03bc791f = L.polygon(
#                 [[-8.0, -60.0], [-8.5, -60.0], [-8.5, -59.5], [-8.0, -59.5], [-8.0, -60.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_acb353ae6e106787cf5a880d39f17a5a);
#
#
#         var popup_8c980d2374d72ea913d84ebaf9fd6b2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e70d3bbff9a8860cfe1cafb47c1249b = $(`&lt;div id=&quot;html_8e70d3bbff9a8860cfe1cafb47c1249b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Área Desmatada 1 (Amazônia)&lt;/b&gt;&lt;br&gt;Desmatamento recente para pastagem.&lt;/div&gt;`)[0];
#                 popup_8c980d2374d72ea913d84ebaf9fd6b2e.setContent(html_8e70d3bbff9a8860cfe1cafb47c1249b);
#
#
#
#         polygon_17388cdc1e887db21dc0df5e03bc791f.bindPopup(popup_8c980d2374d72ea913d84ebaf9fd6b2e)
#         ;
#
#
#
#
#             var polygon_8bce1fbbe652923327ea5738d069004a = L.polygon(
#                 [[-13.0, -47.0], [-13.2, -47.0], [-13.2, -46.8], [-13.0, -46.8], [-13.0, -47.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_acb353ae6e106787cf5a880d39f17a5a);
#
#
#         var popup_cd9b6485399186fa7e3856e47975dd71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ec6bbcdeb5af20583ca53e947ed3e93 = $(`&lt;div id=&quot;html_8ec6bbcdeb5af20583ca53e947ed3e93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Área Desmatada 2 (Cerrado)&lt;/b&gt;&lt;br&gt;Expansão de monoculturas.&lt;/div&gt;`)[0];
#                 popup_cd9b6485399186fa7e3856e47975dd71.setContent(html_8ec6bbcdeb5af20583ca53e947ed3e93);
#
#
#
#         polygon_8bce1fbbe652923327ea5738d069004a.bindPopup(popup_cd9b6485399186fa7e3856e47975dd71)
#         ;
#
#
#
#
#             var circle_7c8c8299c5a216e4bf20727677215874 = L.circle(
#                 [-17.5, -50.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round

# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
import geopandas as gpd
import numpy as np

# --- Caminho para o seu arquivo CSV ---
caminho_arquivo_cruzado = 'dados_rebanhos_prodes_cruzado.csv'

try:
    df_cruzado = pd.read_csv(caminho_arquivo_cruzado, sep=',', encoding='utf-8')

    print(f"Dados cruzados carregados com sucesso! Total de registros: {len(df_cruzado)}")
    print("Primeiras 5 linhas do DataFrame Cruzado ANTES de renomear:")
    print(df_cruzado.head())

    # --- Renomeando as colunas ---
    df_cruzado.rename(columns={
        'desmatado': 'desmatamento_km2',
        'quantidade': 'total_bovinos',
        'id_municipio_nome_x': 'municipio' # Renomeando para usar no tooltip do mapa
    }, inplace=True)

    # Filtrar apenas para o tipo de rebanho 'Bovino' se você quiser focar apenas neles
    # Se seu CSV já está filtrado, essa linha não é estritamente necessária, mas é uma boa prática
    df_cruzado = df_cruzado[df_cruzado['tipo_rebanho'] == 'Bovino'].copy()

    print("\nPrimeiras 5 linhas do DataFrame Cruzado DEPOIS de renomear:")
    print(df_cruzado.head())
    print("\nColunas do DataFrame Cruzado DEPOIS de renomear:")
    print(df_cruzado.columns)

    # Convertendo id_municipio para string para garantir compatibilidade com geometrias
    df_cruzado['id_municipio'] = df_cruzado['id_municipio'].astype(str)

except FileNotFoundError:
    print(f"ERRO: O arquivo '{caminho_arquivo_cruzado}' não foi encontrado.")
except Exception as e:
    print(f"ERRO ao carregar ou processar o arquivo CSV: {e}")
# Out:
# Dados cruzados carregados com sucesso! Total de registros: 886605
# Primeiras 5 linhas do DataFrame Cruzado ANTES de renomear:
#     ano sigla_uf sigla_uf_nome  id_municipio id_municipio_nome_x tipo_rebanho  \
# 0  2013       AC          Acre       1200013          Acrelândia       Bovino
# 1  2013       AC          Acre       1200054        Assis Brasil       Bovino
# 2  2013       AC          Acre       1200104           Brasiléia       Bovino
# 3  2013       AC          Acre       1200138              Bujari       Bovino
# 4  2013       AC          Acre       1200179            Capixaba       Bovino
#
#    quantidade id_municipio_nome_y     bioma  area_total  desmatado  \
# 0      176318          Acrelândia  Amazônia  1819.49772     1078.4
# 1       39318        Assis Brasil  Amazônia  4979.44236      252.5
# 2      202584           Brasiléia  Amazônia  3927.09573     1281.5
# 3      206059              Bujari  Amazônia  3017.16052     1175.6
# 4      147187            Capixaba  Amazônia  1716.90194      848.0
#
#    vegetacao_natural  nao_vegetacao_natural  hidrografia
# 0              741.1                    0.0          0.0
# 1             4726.6                    0.3          0.0
# 2             2645.4                    0.0          0.2
# 3             1841.4                    0.0          0.2
# 4              868.9                    0.0          0.0
#
# Primeiras 5 linhas do DataFrame Cruzado DEPOIS de renomear:
#     ano sigla_uf sigla_uf_nome  id_municipio     municipio tipo_rebanho  \
# 0  2013       AC          Acre       1200013    Acrelândia       Bovino
# 1  2013       AC          Acre       1200054  Assis Brasil       Bovino
# 2  2013       AC          Acre       1200104     Brasiléia       Bovino
# 3  2013       AC          Acre       1200138        Bujari       Bovino
# 4  2013       AC          Acre       1200179      Capixaba       Bovino
#
#    total_bovinos id_municipio_nome_y     bioma  area_total  desmatamento_km2  \
# 0         176318          Acrelândia  Amazônia  1819.49772            1078.4
# 1          39318        Assis Brasil  Amazônia  4979.44236             252.5
# 2         202584           Brasiléia  Amazônia  3927.09573            1281.5
# 3         206059              Bujari  Amazônia  3017.16052            1175.6
# 4         147187            Capixaba  Amazônia  1716.90194             848.0
#
#    vegetacao_natural  nao_vegetacao_natural  hidrografia
# 0              741.1                    0.0          0.0
# 1             4726.6                    0.3          0.0
# 2             2645.4                    0.0          0.2
# 3             1841.4                    0.0          0.2
# 4              868.9                    0.0          0.0
#
# Colunas do DataFrame Cruzado DEPOIS de renomear:
# Index(['ano', 'sigla_uf', 'sigla_uf_nome', 'id_municipio', 'municipio',
#        'tipo_rebanho', 'total_bovinos', 'id_municipio_nome_y', 'bioma',
#        'area_total', 'desmatamento_km2', 'vegetacao_natural',
#        'nao_vegetacao_natural', 'hidrografia'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np # Importar numpy para np.log1p se for usar no mapa

# Assumo que 'df_cruzado' já está carregado e com as colunas renomeadas no seu ambiente Jupyter

# Agregando os dados para o nível nacional anual
df_nacional_anual = df_cruzado.groupby('ano').agg(
    desmatamento_km2=('desmatamento_km2', 'sum'),
    total_bovinos=('total_bovinos', 'sum')
).reset_index()

print("Dados Nacionais Anuais Agregados para o Gráfico:")
print(df_nacional_anual.head())

# --- Criar o Gráfico de Dispersão com Linhas ---
plt.figure(figsize=(10, 6))

# Plotar os pontos de dispersão (cada ponto representa um ano)
plt.scatter(df_nacional_anual['desmatamento_km2'], df_nacional_anual['total_bovinos'],
            color='blue', alpha=0.7, s=80, label='Dados Anuais') # s=80 para pontos maiores

# Adicionar linhas conectando os pontos na ordem cronológica (pelo ano)
df_nacional_anual_sorted = df_nacional_anual.sort_values(by='ano')
plt.plot(df_nacional_anual_sorted['desmatamento_km2'], df_nacional_anual_sorted['total_bovinos'],
         color='red', linestyle='--', linewidth=1.5, alpha=0.7, label='Progresso Temporal')

# Adicionar rótulos e título
plt.title('Correlação entre Desmatamento (PRODES) e Efetivo de Bovinos (PPM) no Brasil', fontsize=14)
plt.xlabel('Desmatamento Anual (km²)', fontsize=12)
plt.ylabel('Efetivo de Bovinos (cabeças)', fontsize=12)

# Anotar os anos em cada ponto para facilitar a visualização da progressão
for i, row in df_nacional_anual_sorted.iterrows():
    plt.annotate(f"{int(row['ano'])}", (row['desmatamento_km2'], row['total_bovinos']),
                 textcoords="offset points", xytext=(5,5), ha='center', fontsize=9, color='darkgreen')

# Adicionar uma grade para facilitar a leitura
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.tight_layout() # Ajusta o layout para evitar sobreposição
plt.show()

# --- Calcular e exibir o coeficiente de correlação de Pearson ---
correlation_coefficient = df_nacional_anual['desmatamento_km2'].corr(df_nacional_anual['total_bovinos'])
print(f"\n**Coeficiente de Correlação de Pearson (Desmatamento x Bovinos, Nacional Anual): {correlation_coefficient:.2f}**")

if correlation_coefficient > 0.7:
    print("Isso sugere uma correlação positiva forte: à medida que o desmatamento aumenta, o efetivo de bovinos também tende a aumentar.")
elif correlation_coefficient < -0.7:
    print("Isso sugere uma correlação negativa forte: à medida que o desmatamento aumenta, o efetivo de bovinos tende a diminuir.")
elif 0.3 <= correlation_coefficient <= 0.7:
    print("Isso sugere uma correlação positiva moderada.")
elif -0.7 <= correlation_coefficient <= -0.3:
    print("Isso sugere uma correlação negativa moderada.")
else:
    print("Isso sugere uma correlação linear fraca ou inexistente.")
# Out:
# Dados Nacionais Anuais Agregados para o Gráfico:
#     ano  desmatamento_km2  total_bovinos
# 0  2000         2216033.6      217010978
# 1  2001         2338261.1      224551052
# 2  2002         2409564.8      235455935
# 3  2003         2488674.2      248401228
# 4  2004         2564256.0      258313654
# **Coeficiente de Correlação de Pearson (Desmatamento x Bovinos, Nacional Anual): 0.93**
# Isso sugere uma correlação positiva forte: à medida que o desmatamento aumenta, o efetivo de bovinos também tende a aumentar.
